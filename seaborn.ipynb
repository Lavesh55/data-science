# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tip=sns.load_dataset('tips')
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tip['total_bill'].max()
# Out:
# np.float64(50.81)

# %%
plt.plot(tip['total_bill'])
plt.show()

# %%
sns.scatterplot(x='total_bill',y='tip',data=tip)
plt.show()

# %%
sns.histplot(tip['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
plt.hist(tip['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.kdeplot(tip['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.relplot(x='total_bill',y='tip',data=tip,kind='scatter',hue='time')

# %%
sns.relplot(x='total_bill',y='tip',data=tip,kind='scatter',hue='time',style='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=tip,kind='scatter',hue='time',style='smoker',col='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=tip,kind='scatter',hue='time',row='time')

# %%
sns.catplot(x='day',y='total_bill',data=tip,kind='strip')

# %%
sns.catplot(x='day',y='total_bill',data=tip,kind='swarm')

# %%
sns.catplot(x='day',y='total_bill',data=tip,kind='violin')

# %%
sns.catplot(x='day',y='total_bill',data=tip,kind='bar')

# %%
sns.catplot(x='day',y='total_bill',data=tip,kind='box')

# %%
sns.catplot(x='day',y='total_bill',data=tip,kind='boxen')

# %%
plt.figure(figsize=(8,8))
sns.countplot(tip['day'])
plt.show()

# %%
sns.boxplot(tip['total_bill'])
plt.show()

# %%
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000
