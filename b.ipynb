# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Bengaluru_House_Data.csv")

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(529)

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.shape[0]-df.duplicated().sum()
# Out:
# np.int64(12791)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13308        Built-up  Area  Ready To Move         Bannerghatta Road
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
cat_col=df.select_dtypes(include="O")
cat_col
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft
# 0          2 BHK  Coomee        1056
# 1      4 Bedroom  Theanmp       2600
# ...

# %%
# cat_col['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1521', ..., '1919', '2111', '4689'], dtype=object)

# %%
# dt5={i:key for key , i in enumerate(list(cat_col['total_sqft'].unique()))}
# dt5
# Out:
# {'1056': 0,
#  '2600': 1,
#  '1521': 2,
#  '1170': 3,
#  '2785': 4,
#  '1000': 5,
#  '2250': 6,
#  '1175': 7,
#  '1180': 8,
#  '1540': 9,
#  '2770': 10,
#  '1755': 11,
#  '2800': 12,
#  '510': 13,
#  '660': 14,
#  '1151': 15,
#  '1025': 16,
#  '2100 - 2850': 17,
#  '1075': 18,
#  '1760': 19,
#  '1693': 20,
#  '700': 21,
#  '1724': 22,
#  '1254': 23,
#  '600': 24,
#  '1330.74': 25,
#  '970': 26,
#  '1459': 27,
#  '1270': 28,
#  '1670': 29,
#  '2010': 30,
#  '1185': 31,
#  '1600': 32,
#  '1200': 33,
#  '1500': 34,
#  '845': 35,
#  '5700': 36,
#  '1160': 37,
#  '1140': 38,
#  '1358': 39,
#  '1569': 40,
#  '1240': 41,
#  '2089': 42,
#  '2511': 43,
#  '1660': 44,
#  '1326': 45,
#  '1499': 46,
#  '708': 47,
#  '1060': 48,
#  '1296': 49,
#  '2894': 50,
#  '2502': 51,
#  '650': 52,
#  '2400': 53,
#  '1007': 54,
#  '1640': 55,
#  '1260': 56,
#  '1413': 57,
#  '1116': 58,
#  '1530': 59,
#  '2497': 60,
#  '1427': 61,
#  '2061': 62,
#  '3067 - 8156': 63,
#  '1282': 64,
#  '1870': 65,
# ...

# %%
# lst=[]
# for x ,y in enumerate(dt5):
#     # print(x)
    
#     lst.append(y)
# print(lst)
# Out:
# ['1056', '2600', '1521', '1170', '2785', '1000', '2250', '1175', '1180', '1540', '2770', '1755', '2800', '510', '660', '1151', '1025', '2100 - 2850', '1075', '1760', '1693', '700', '1724', '1254', '600', '1330.74', '970', '1459', '1270', '1670', '2010', '1185', '1600', '1200', '1500', '845', '5700', '1160', '1140', '1358', '1569', '1240', '2089', '2511', '1660', '1326', '1499', '708', '1060', '1296', '2894', '2502', '650', '2400', '1007', '1640', '1260', '1413', '1116', '1530', '2497', '1427', '2061', '3067 - 8156', '1282', '1870', '880', '1535', '950', '1360', '1042 - 1105', '3050', '1563.05', '1167', '890', '1612', '1710', '957', '1125', '1020', '1735', '2050', '1063', '1904', '2000', '1145 - 1340', '1425', '1470', '450', '1152', '1350', '1550', '705', '770', '1242', '1700', '2144', '1704', '1070', '1015 - 1540', '1327', '1400', '1225', '1909', '1359', '1595', '1475', '1580', '1295', '589', '1787', '984', '2405', '1080', '1153', '1148', '1110', '1100', '1290', '1933', '645', '1644'
# ...

# %%
num_col=df.select_dtypes(exclude="O")
num_col
# Out:
#        bath  balcony   price
# 0       2.0      1.0   39.07
# 1       5.0      3.0  120.00
# 2       2.0      3.0   62.00
# 3       3.0      1.0   95.00
# 4       2.0      1.0   51.00
# ...     ...      ...     ...
# 13314   3.0      3.0  112.00
# 13315   4.0      0.0  231.00
# 13316   5.0      NaN  400.00
# 13317   2.0      1.0   60.00
# 13318   4.0      1.0  488.00
#
# [12791 rows x 3 columns]

# %%
num_col.isnull().sum()
# Out:
# bath        73
# balcony    605
# price        0
# dtype: int64

# %%
num_col.dropna(inplace=True)

# %%
num_col.isnull().sum()
# Out:
# bath       0
# balcony    0
# price      0
# dtype: int64

# %%
num_col
# Out:
#        bath  balcony   price
# 0       2.0      1.0   39.07
# 1       5.0      3.0  120.00
# 2       2.0      3.0   62.00
# 3       3.0      1.0   95.00
# 4       2.0      1.0   51.00
# ...     ...      ...     ...
# 13312   2.0      2.0   47.00
# 13314   3.0      3.0  112.00
# 13315   4.0      0.0  231.00
# 13317   2.0      1.0   60.00
# 13318   4.0      1.0  488.00
#
# [12186 rows x 3 columns]

# %%
cat_col.dropna(inplace=True)

# %%
cat_col.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# dtype: int64

# %%
cat_col=cat_col.drop(["total_sqft"],axis=1)
cat_col
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 6      Super built-up  Area         18-May          Old Airport Road
# ...                     ...            ...                       ...
# 13309  Super built-up  Area  Ready To Move              Yeshwanthpur
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society
# 0          2 BHK  Coomee
# 1      4 Bedroom  Theanmp
# 3          3 BHK  Soiewre
# 5          2 BHK  DuenaTa
# ...

# %%
cat_col['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
df1={'Super built-up  Area':1, 'Plot  Area':2, 'Built-up  Area':3,'Carpet  Area':4}
df1
# Out:
# {'Super built-up  Area': 1,
#  'Plot  Area': 2,
#  'Built-up  Area': 3,
#  'Carpet  Area': 4}

# %%
cat_col["area_type"]=cat_col["area_type"].map(df1)

# %%
cat_col['availability'].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-May', '18-Nov', '17-Oct', '21-Dec',
#        '19-Sep', '20-Sep', '18-Mar', '20-Feb', '18-Apr', '20-Aug',
#        '18-Oct', '19-Mar', '17-Sep', '17-Aug', '19-Apr', '22-Dec',
#        '18-Aug', '19-Jan', '17-Jul', '18-Jul', '18-Dec', '21-Jun',
#        '18-Sep', '17-May', '17-Jun', '21-May', '20-Dec', '18-Jun',
#        '16-Mar', '22-Jun', '17-Dec', '21-Feb', '19-May', '17-Nov',
#        '20-Oct', '20-Jun', '18-Feb', '19-Feb', '21-Oct', '21-Jan',
#        '17-Mar', '19-Jun', '17-Apr', '22-May', '19-Oct', '21-Jul',
#        '21-Nov', '21-Mar', '19-Jul', '20-Jan', '21-Sep', '18-Jan',
#        '20-Mar', '19-Nov', '15-Nov', '15-Jun', '19-Aug', '20-May',
#        '20-Nov', '20-Jul', '15-Oct', '15-Dec', '21-Aug', '16-Oct',
#        '22-Nov', '16-Dec', '15-Aug', '17-Jan', '16-Nov', '20-Apr',
#        '22-Jan', '16-Jan', '17-Feb', '14-Jul'], dtype=object)

# %%
# cat_col.drop_duplicates(inplace=True)
cat_col["availability"].duplicated().sum()
# Out:
# np.int64(4510)

# %%
df2={'19-Dec':1, 'Ready To Move':2, '18-May':3, '18-Nov':4, '17-Oct':5, '21-Dec':6,'19-Sep':7, '20-Sep':8, '18-Mar':9, '20-Feb':10, '18-Apr':11, '20-Aug':12,'18-Oct':13, '19-Mar':14, '17-Sep':18, '17-Aug':19, '19-Apr':20, '22-Dec':21,'18-Aug':22, '19-Jan':23, '17-Jul':24, '18-Jul':25, '18-Dec':26, '21-Jun':27,'18-Sep':28, '17-May':29, '17-Jun':30, '21-May':31, '20-Dec':32, '18-Jun':33,'16-Mar':34, '22-Jun':35, '17-Dec':36, '21-Feb':37, '19-May':38, '17-Nov':39,'20-Oct':40, '20-Jun':41, '18-Feb':42, '19-Feb':43, '21-Oct':44, '21-Jan':45,'17-Mar':46, '19-Jun':47, '17-Apr':48, '22-May':49, '19-Oct':50, '21-Jul':51,'21-Nov':52, '21-Mar':53, '19-Jul':54, '20-Jan':55, '21-Sep':56, '18-Jan':57,'20-Mar':58, '19-Nov':59, '15-Nov':60, '15-Jun':61, '19-Aug':62, '20-May':63,'20-Nov':64, '20-Jul':65, '15-Oct':66, '15-Dec':67, '21-Aug':68, '16-Oct':69,'22-Nov':70, '16-Dec':71, '15-Aug':72, '17-Jan':73, '16-Nov':74, '20-Apr':75,'22-Jan':76, '16-Jan':77, '17-Feb':78, '14-Jul':79}
df2
# Out:
# {'19-Dec': 1,
#  'Ready To Move': 2,
#  '18-May': 3,
#  '18-Nov': 4,
#  '17-Oct': 5,
#  '21-Dec': 6,
#  '19-Sep': 7,
#  '20-Sep': 8,
#  '18-Mar': 9,
#  '20-Feb': 10,
#  '18-Apr': 11,
#  '20-Aug': 12,
#  '18-Oct': 13,
#  '19-Mar': 14,
#  '17-Sep': 18,
#  '17-Aug': 19,
#  '19-Apr': 20,
#  '22-Dec': 21,
#  '18-Aug': 22,
#  '19-Jan': 23,
#  '17-Jul': 24,
#  '18-Jul': 25,
#  '18-Dec': 26,
#  '21-Jun': 27,
#  '18-Sep': 28,
#  '17-May': 29,
#  '17-Jun': 30,
#  '21-May': 31,
#  '20-Dec': 32,
#  '18-Jun': 33,
#  '16-Mar': 34,
#  '22-Jun': 35,
#  '17-Dec': 36,
#  '21-Feb': 37,
#  '19-May': 38,
#  '17-Nov': 39,
#  '20-Oct': 40,
#  '20-Jun': 41,
#  '18-Feb': 42,
#  '19-Feb': 43,
#  '21-Oct': 44,
#  '21-Jan': 45,
#  '17-Mar': 46,
#  '19-Jun': 47,
#  '17-Apr': 48,
#  '22-May': 49,
#  '19-Oct': 50,
#  '21-Jul': 51,
#  '21-Nov': 52,
#  '21-Mar': 53,
#  '19-Jul': 54,
#  '20-Jan': 55,
#  '21-Sep': 56,
#  '18-Jan': 57,
#  '20-Mar': 58,
#  '19-Nov': 59,
#  '15-Nov': 60,
#  '15-Jun': 61,
# ...

# %%
cat_col["availability"].duplicated().sum()
# Out:
# np.int64(4510)

# %%
cat_col["availability"]=cat_col["availability"].map(df2)

# %%
cat_col
# Out:
#        area_type  availability                  location       size  society
# 0              1             1  Electronic City Phase II      2 BHK  Coomee
# 1              2             2          Chikka Tirupathi  4 Bedroom  Theanmp
# 3              1             2        Lingadheeranahalli      3 BHK  Soiewre
# 5              1             2                Whitefield      2 BHK  DuenaTa
# 6              1             3          Old Airport Road      4 BHK  Jaades
# ...          ...           ...                       ...        ...      ...
# 13309          1             2              Yeshwanthpur      3 BHK  IBityin
# 13314          1             2         Green Glen Layout      3 BHK  SoosePr
# 13315          3             2                Whitefield  5 Bedroom  ArsiaEx
# 13317          3             2     Raja Rajeshwari Nagar      2 BHK  Mahla T
# 13318          1            33           Padmanabhanagar      4 BHK  SollyCl
#
# [7449 rows x 5 columns]

# %%
complete_col=pd.concat([cat_col,num_col],axis=1)
complete_col
# Out:
#        area_type  availability                  location       size  society  \
# 0            1.0           NaN  Electronic City Phase II      2 BHK  Coomee
# 1            2.0           NaN          Chikka Tirupathi  4 Bedroom  Theanmp
# 3            1.0           NaN        Lingadheeranahalli      3 BHK  Soiewre
# 5            1.0           NaN                Whitefield      2 BHK  DuenaTa
# 6            1.0           NaN          Old Airport Road      4 BHK  Jaades
# ...          ...           ...                       ...        ...      ...
# 13307        NaN           NaN                       NaN        NaN      NaN
# 13310        NaN           NaN                       NaN        NaN      NaN
# 13312        NaN           NaN                       NaN        NaN      NaN
# 13314        NaN           NaN                       NaN        NaN      NaN
# 13317        NaN           NaN                       NaN        NaN      NaN
#
#        bath  balcony   price
# ...

# %%
x=complete_col.drop("price",axis=1)
y=complete_col[["price"]]

# %%
from sklearn.model_selection import train_test_split

# %%
x.isnull().sum()
# Out:
# area_type        7810
# availability    12396
# location         7810
# size             7810
# society          7810
# bath              210
# balcony           210
# dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#        area_type  availability            location   size  society  bath  \
# 5242         3.0           NaN  7th Phase JP Nagar  3 BHK  Kaiew L   3.0
# 5411         NaN           NaN                 NaN    NaN      NaN   2.0
# 8573         NaN           NaN                 NaN    NaN      NaN   4.0
# 5701         NaN           NaN                 NaN    NaN      NaN   4.0
# 10185        3.0           NaN            Sarjapur  3 BHK  Coa It    3.0
# ...          ...           ...                 ...    ...      ...   ...
# 12624        NaN           NaN                 NaN    NaN      NaN   2.0
# 1375         NaN           NaN                 NaN    NaN      NaN   3.0
# 1769         NaN           NaN                 NaN    NaN      NaN   6.0
# 1664         1.0           NaN         Hennur Road  2 BHK  Puachal   2.0
# 5112         NaN           NaN                 NaN    NaN      NaN   8.0
#
#        balcony
# 5242       1.0
# 5411       2.0
# 8573       3.0
# 5701       1.0
# ...

# %%
y_train
# Out:
#         price
# 5242    70.00
# 5411    44.81
# 8573   220.00
# 5701   375.00
# 10185   55.00
# ...       ...
# 12624   75.00
# 1375    93.00
# 1769    66.00
# 1664    89.00
# 5112   220.00
#
# [9916 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression

# %%
x_train.isnull().sum()
# Out:
# area_type       6268
# availability    9916
# location        6268
# size            6268
# society         6268
# bath             161
# balcony          161
# dtype: int64

# %%
y_train.isnull().sum()
# Out:
# price    161
# dtype: int64

# %%
x_train
# Out:
#        area_type  availability            location   size  society  bath  \
# 5242         3.0           NaN  7th Phase JP Nagar  3 BHK  Kaiew L   3.0
# 5411         NaN           NaN                 NaN    NaN      NaN   2.0
# 8573         NaN           NaN                 NaN    NaN      NaN   4.0
# 5701         NaN           NaN                 NaN    NaN      NaN   4.0
# 10185        3.0           NaN            Sarjapur  3 BHK  Coa It    3.0
# ...          ...           ...                 ...    ...      ...   ...
# 12624        NaN           NaN                 NaN    NaN      NaN   2.0
# 1375         NaN           NaN                 NaN    NaN      NaN   3.0
# 1769         NaN           NaN                 NaN    NaN      NaN   6.0
# 1664         1.0           NaN         Hennur Road  2 BHK  Puachal   2.0
# 5112         NaN           NaN                 NaN    NaN      NaN   8.0
#
#        balcony
# 5242       1.0
# 5411       2.0
# 8573       3.0
# 5701       1.0
# ...

# %%
lr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12412\3557823984.py in ?()
# ----> 1 lr.fit(x_train,y_train)
#
# ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1462                 fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1463             )
#    1464
#    1465             if not global_skip_validation and not partial_fit_and_fitted:
# -> 1466                 estimator._validate_params()
#    1467
#    1468             with config_context(
#    1469                 skip_parameter_validation=(
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
# ...
